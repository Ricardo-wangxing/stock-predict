# %%
from keras.models import load_model
base_dir = 'G:\\models'

# %%
import os

model = load_model(os.path.join(base_dir,'159915.XSHE.h5'))
model.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_42 (GRU)                (None, 30, 50)            7950
#
#  dropout_33 (Dropout)        (None, 30, 50)            0
#
#  gru_43 (GRU)                (None, 30, 50)            15300
#
#  gru_44 (GRU)                (None, 50)                15300
#
#  dropout_34 (Dropout)        (None, 50)                0
#
#  dense_15 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 38,601
# Trainable params: 38,601
# Non-trainable params: 0
# _________________________________________________________________

# %%
dr_layer = model.get_layer(index=4)

# %%
dr_layer.rate
# Out:
# 0.3

# %%
from keras.utils.vis_utils import plot_model

# %%
plot_model(model,to_file='D:\\test.png',show_dtype=True,show_shapes=True)

# %%
import os
os.environ['PATH'] += os.pathsep + r'C:\Program Files\Graphviz\bin'

# %%
from keras.utils import print_summary
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_49404/3824375037.py in <module>
# ----> 1 from keras.utils import print_summary
#
# ImportError: cannot import name 'print_summary' from 'keras.utils' (c:\Users\12554\miniconda3\lib\site-packages\keras\utils\__init__.py)
